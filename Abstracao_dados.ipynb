# %%
import pandas as pd

df = pd.read_excel('Result_28.xlsx')

# %%
if __name__ == "__main__":

    print("Valores nulos restantes por coluna:")
    print(df.isnull().sum())
# Out:
# Valores nulos restantes por coluna:
# tipo_ticket                0
# problema_nosso         21673
# servico                19997
# meio                       0
# status_cliente             0
# categoria               2440
# hist                   19214
# codcli                     0
# consultor                  4
# classificacao              0
# data_criacao_ticket        0
# id_ticket                  0
# titulo                    11
# colaborador            26703
# data_atualizacao           0
# duracao                47016
# mensagem                2919
# dtype: int64

# %%
# 1. Tratamento do tempo e criação da coluna de minutos
df["duracao"] = df["duracao"].fillna("00:00:00")
df["duracao"] = pd.to_timedelta(df["duracao"], errors="coerce")
df["data_atualizacao"] = pd.to_datetime(df["data_atualizacao"], errors="coerce")

# Converter durações para formato HH:MM:SS (string) removendo 'days'
df['duracao_minutos_individual'] = df['duracao'].astype(str).str.replace(r'^(\d+ days?\s+)?', '', regex=True).str.split('.').str[0]

# 2. Somar a duração por ticket e criar coluna separada
df['duracao_minutos_total_por_ticket'] = df.groupby('id_ticket')['duracao'].transform('sum').astype(str).str.split('.').str[0]


# 3. Lista de colunas que NÃO queremos que o preenchimento automático toque
# (duracao já está preenchida, mensagem não será alterada, id_ticket é a chave)
colunas_ignoradas = ['id_ticket', 'duracao', 'duracao_minutos_individual', 'mensagem', 'duracao_minutos_total_por_ticket']

# Criar a lista de colunas para preencher (todas as outras colunas)
colunas_para_preencher = [col for col in df.columns if col not in colunas_ignoradas]

# 4. Preencher as lacunas em bloco (bfill e ffill) para cada ticket
df[colunas_para_preencher] = df.groupby('id_ticket')[colunas_para_preencher].transform(
    lambda x: x.bfill().ffill()
)
# 5. Remover a coluna de duração original, pois agora temos as colunas de minutos
df = df.drop('duracao', axis=1)

# 6. Remover os status pendentes, pois não são mais relevantes para a análise
df = df[df["status_cliente"].isin(["FECHADO"])]
df = df.dropna(subset=["status_cliente"])

# 7. Preencher valores nulos na coluna "problema_nosso"
df["problema_nosso"] = df["problema_nosso"].fillna("Indefinido", inplace= True)

# 8. Preencher valores nulos na coluna "servico"
df['servico'] = df['servico'].fillna("Serviço Indefinido", inplace= True)

# 9. Preencher valores nulos na coluna "categoria"
df['categoria'] = df['categoria'].fillna("Categoria Indefinida", inplace= True)

# 10. Preencher valores nulos na coluna "hist"
df['hist'] = df['hist'].fillna("Versão Indefinido", inplace= True)

# 11. Preencher valores nulos na coluna "consultor"
df['consultor'] = df['consultor'].fillna("Indefinido", inplace= True)

# 12. Preencher valores nulos na coluna "titulo"
df['titulo'] = df['titulo'].fillna("Sem título", inplace= True)

# 13. Preencher valores nulos na coluna "colaborador"
df['colaborador'] = df['colaborador'].fillna("Colaborador Indefinido", inplace= True)

# 14. Preencher valores nulos na coluna "data_atualizacao"
df['data_atualizacao'] = df['data_atualizacao'].fillna("00:00:00")

# 15. Preencher valores nulos na coluna "mensagem" e limpar caracteres de quebra de linha
df['mensagem'] = df['mensagem'].fillna("Sem mensagem", inplace= True)
# Remove "mailto:"
df["mensagem"] = df["mensagem"].str.replace("mailto:", "", regex=False)
# Remove emails
df["mensagem"] = df["mensagem"].str.replace(
    r'\S+@\S+',
    '',
    regex=True
)
# Remove entidades HTML &nbsp;
df["mensagem"] = df["mensagem"].str.replace("&nbsp;", " ", regex=False)
# Remove espaços extras novamente
df["mensagem"] = df["mensagem"].str.replace(r'\s+', ' ', regex=True).str.strip()

# 16. Ordenar categoria por ordem alfabética
ordem = ["A", "B", "C"]

df["classificacao"] = pd.Categorical(
    df["classificacao"],
    categories=ordem,
    ordered=True
)

df = df.sort_values("classificacao")

                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               
if __name__ == "__main__":

    print("Valores nulos restantes por coluna:")
    print(df.isnull().sum())
# Out:
# C:\Users\LucBiel\AppData\Local\Temp\ipykernel_6660\1561593230.py:32: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["problema_nosso"] = df["problema_nosso"].fillna("Indefinido", inplace= True)
# C:\Users\LucBiel\AppData\Local\Temp\ipykernel_6660\1561593230.py:35: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['servico'] = df['servico'].fillna("Serviço Indefinido", inplace= True)
# C:\Users\LucBiel\AppData\Local\Temp\ipykernel_6660\1561593230.py:38: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['categoria'] = df['categoria'].fillna("Categoria Indefinida", inplace= True)
# C:\Users\LucBiel\AppData\Local\Temp\ipykernel_6660\1561593230.py:41: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['hist'] = df['hist'].fillna("Versão Indefinido", inplace= True)
# C:\Users\LucBiel\AppData\Local\Temp\ipykernel_6660\1561593230.py:44: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['consultor'] = df['consultor'].fillna("Indefinido", inplace= True)
# C:\Users\LucBiel\AppData\Local\Temp\ipykernel_6660\1561593230.py:47: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['titulo'] = df['titulo'].fillna("Sem título", inplace= True)
# C:\Users\LucBiel\AppData\Local\Temp\ipykernel_6660\1561593230.py:50: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['colaborador'] = df['colaborador'].fillna("Colaborador Indefinido", inplace= True)
# C:\Users\LucBiel\AppData\Local\Temp\ipykernel_6660\1561593230.py:56: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['mensagem'] = df['mensagem'].fillna("Sem mensagem", inplace= True)
# Valores nulos restantes por coluna:
# tipo_ticket                         0
# problema_nosso                      0
# servico                             0
# meio                                0
# status_cliente                      0
# categoria                           0
# hist                                0
# codcli                              0
# consultor                           0
# classificacao                       0
# data_criacao_ticket                 0
# id_ticket                           0
# titulo                              0
# colaborador                         0
# data_atualizacao                    0
# mensagem                            0
# duracao_minutos_individual          0
# duracao_minutos_total_por_ticket    0
# dtype: int64

# %%
df
# Out:
#        tipo_ticket problema_nosso             servico            meio  \
# 43108      suporte     Indefinido  Serviço Indefinido  Portal Cliente
# 90135      suporte            SIM            Fortinet  Portal Cliente
# 39400      suporte            SIM            Fortinet  Portal Cliente
# 39401      suporte            SIM            Fortinet  Portal Cliente
# 39402      suporte            SIM            Fortinet  Portal Cliente
# ...            ...            ...                 ...             ...
# 56537      suporte            SIM     Acesso Dedicado        WhatsApp
# 56536      suporte            SIM     Acesso Dedicado        WhatsApp
# 56535      suporte            SIM     Acesso Dedicado        WhatsApp
# 56531      suporte            SIM     Acesso Dedicado        WhatsApp
# 103089     suporte     Indefinido              E-mail        Telefone
#
#        status_cliente         categoria  \
# 43108         FECHADO  Nova Solicitação
# 90135         FECHADO  Nova Solicitação
# 39400         FECHADO  Nova Solicitação
# 39401         FECHADO  Nova Solicitação
# 39402         FECHADO  Nova Solicitação
# ...               ...               ...
# 56537         FECHADO          Problema
# 56536         FECHADO          Problema
# 56535         FECHADO          Problema
# 56531         FECHADO  Nova Solicitação
# 103089        FECHADO  Nova Solicitação
#
#                                           hist  codcli    consultor  \
# 43108                        Versão Indefinido    5463  Julio Cesar
# 90135   Fortigate 40F s/ lic - Palmas Embrasil    4968      Janaina
# 39400                            Fortigate 80F    2286      Janaina
# 39401                            Fortigate 80F    2286      Janaina
# 39402                            Fortigate 80F    2286      Janaina
# ...                                        ...     ...          ...
# 56537                               Rompimento    6075      CTI-ADM
# 56536                               Rompimento    6075      CTI-ADM
# 56535                               Rompimento    6075      CTI-ADM
# 56531                               Rompimento    4873      CTI-ADM
# 103089                       ref 15 contas 5GB    6425       Karina
#
#        classificacao data_criacao_ticket  id_ticket  \
# 43108              A    2025-06-09 04:55     358272
# 90135              A    2025-11-07 11:55     371606
# 39400              A    2025-05-28 04:55     357296
# 39401              A    2025-05-28 04:55     357296
# 39402              A    2025-05-28 04:55     357296
# ...              ...                 ...        ...
# 56537              C    2025-07-28 08:55     362043
# 56536              C    2025-07-28 08:55     362043
# 56535              C    2025-07-28 08:55     362043
# 56531              C    2025-07-26 01:55     362033
# 103089             C    2025-12-31 01:66     375600
#
#                                                    titulo colaborador  \
# 43108                                        Liberar site   Cleverton
# 90135                          Embrasil - Palmas Voip 3cx  João Paulo
# 39400              Incluir servidores na regra do anydesk       Lucas
# 39401              Incluir servidores na regra do anydesk       Lucas
# 39402              Incluir servidores na regra do anydesk       Lucas
# ...                                                   ...         ...
# 56537                   Rompimento - MKT LOG - 28/07/2025       Allan
# 56536                   Rompimento - MKT LOG - 28/07/2025       Allan
# 56535                   Rompimento - MKT LOG - 28/07/2025       Allan
# 56531   Rompimento - 5557-SMARTS_AVENIDA_POMPEIA-LD e ...    Ermerson
# 103089  Painel de cliente - Alteração - Atualização de...      Thiago
#
#           data_atualizacao                                           mensagem  \
# 43108  2025-06-09 04:55:00                                       Liberar site
# 90135  2025-11-07 01:55:00  Prezados, boa tarde.Configuração realizada par...
# 39400  2025-05-28 04:55:00             Incluir servidores na regra do anydesk
# 39401  2025-05-28 04:55:00  Prezados,Boa tarde.Preciso que seja incluído n...
# 39402  2025-05-28 05:55:00  Navito, boa tarde!Conforme as regras criadas a...
# ...                    ...                                                ...
# 56537  2025-07-28 03:55:00                                       Sem mensagem
# 56536  2025-07-28 08:55:00  Estamos com um rompimento no trecho acima cons...
# 56535  2025-07-28 08:55:00                  Rompimento - MKT LOG - 28/07/2025
# 56531  2025-07-26 07:55:00  https://maps.google.com/?q=-23.5274437,-46.683...
# 103089 2026-05-22 00:00:00  Tentei contato com o cliente pelos números (19...
#
#        duracao_minutos_individual duracao_minutos_total_por_ticket
# 43108                    00:00:00                  0 days 00:03:12
# 90135                    00:07:09                  0 days 00:07:09
# 39400                    00:00:00                  0 days 00:17:00
# 39401                    00:00:00                  0 days 00:17:00
# 39402                    00:04:42                  0 days 00:17:00
# ...                           ...                              ...
# 56537                    00:00:37                  0 days 00:07:14
# 56536                    00:01:12                  0 days 00:07:14
# 56535                    00:00:00                  0 days 00:07:14
# 56531                    00:03:24                  0 days 00:40:30
# 103089                   00:06:12                  0 days 00:39:38
#
# [101849 rows x 18 columns]

# %%
# =========================================================
# FORMAÇÃO DE EQUIPES ESPECIALIZADAS
# =========================================================

# Conta tickets únicos por consultor e serviço
especialistas = (

    df.groupby(['consultor', 'servico'])['id_ticket']

    # evita tickets duplicados
    .nunique()

    .reset_index(name='tickets_resolvidos')
)

# Remove valores nulos
especialistas = especialistas.dropna(
    subset=['consultor', 'servico']
)

# =========================================================
# DEFINE A LINHA MAIS FORTE DE CADA CONSULTOR
# =========================================================

# Ordena da maior experiência para menor
especialistas = especialistas.sort_values(
    by='tickets_resolvidos',
    ascending=False
)

# Mantém apenas o serviço mais forte do operador
linha_mais_forte = (
    especialistas
    .groupby('consultor')
    .head(1)
    .reset_index(drop=True)
)

# =========================================================
# CLASSIFICAÇÃO DE PERFORMANCE
# =========================================================

def classificar_nivel(qtd):

    if qtd >= 1000:
        return 'Especialista'

    elif qtd >= 500:
        return 'Avançado'

    elif qtd >= 200:
        return 'Pleno'

    else:
        return 'Júnior'


linha_mais_forte['nivel_tecnico'] = (
    linha_mais_forte['tickets_resolvidos']
    .apply(classificar_nivel)
)

# =========================================================
# ORGANIZAÇÃO DAS EQUIPES
# =========================================================

equipes_recomendadas = linha_mais_forte.sort_values(
    ['servico', 'tickets_resolvidos'],
    ascending=[True, False]
)

# =========================================================
# RESULTADO FINAL
# =========================================================

print("\n===== EQUIPES MAIS RECOMENDADAS =====\n")

for servico, equipe in equipes_recomendadas.groupby('servico'):

    print(f"\n🔧 SERVIÇO: {servico}")
    print("-" * 50)

    for _, row in equipe.iterrows():

        print(
            f"{row['consultor']} | "
            f"{row['nivel_tecnico']} | "
            f"{row['tickets_resolvidos']} tickets resolvidos"
        )
# Out:
# ===== EQUIPES MAIS RECOMENDADAS =====
#
#
# 🔧 SERVIÇO: Acesso Dedicado
# --------------------------------------------------
# CTI-ADM | Especialista | 1549 tickets resolvidos
# Eduardo Nogueira | Especialista | 1253 tickets resolvidos
# Jeferson | Especialista | 1125 tickets resolvidos
# Elaine | Pleno | 271 tickets resolvidos
# Arnizal | Júnior | 2 tickets resolvidos
#
# 🔧 SERVIÇO: E-mail
# --------------------------------------------------
# Karina | Pleno | 463 tickets resolvidos
#
# 🔧 SERVIÇO: Fortinet
# --------------------------------------------------
# Janaina | Especialista | 4326 tickets resolvidos
# Márcio Takeshi | Especialista | 3304 tickets resolvidos
# Julio Cesar | Especialista | 1609 tickets resolvidos
# Flavio | Pleno | 224 tickets resolvidos
#
# 🔧 SERVIÇO: Serviço Indefinido
# --------------------------------------------------
# Indefinido | Júnior | 2 tickets resolvidos

# %%
import plotly.express as px

# =========================================================
# GRÁFICO - EQUIPES ESPECIALIZADAS
# =========================================================

fig_equipes = px.bar(
    equipes_recomendadas,

    x='tickets_resolvidos',
    y='consultor',

    color='nivel_tecnico',

    orientation='h',

    facet_col='servico',
    facet_col_wrap=2,

    text='tickets_resolvidos',

    title='Especialistas Recomendados por Serviço'
)

# =========================================================
# ESTILIZAÇÃO
# =========================================================

fig_equipes.update_layout(

    height=900,

    paper_bgcolor='white',
    plot_bgcolor='white',

    title_x=0.5,

    font=dict(
        family='Arial',
        size=12
    )
)

fig_equipes.update_traces(
    textposition='outside'
)

# =========================================================
# EXIBIÇÃO
# =========================================================

fig_equipes.show()
